# %% [markdown]
# # Student Mental Health Analysis
#
# ## Notebook 1: Data Profiling
#
# **Author:** Russel P M
#
# **Project:** End-to-End Data Analytics Project
#
# **Tools Used:** Python, Pandas, NumPy, Google Colab

# %% [markdown]
# ## Objective
#
# The objective of this notebook is to perform an initial assessment of the Student Mental Health dataset before any data cleaning or analysis.
#
# The profiling process will help identify:
#
# - Dataset dimensions
# - Column names and data types
# - Missing values
# - Duplicate records
# - Unique values
# - Summary statistics
# - Potential data quality issues
#
# The insights from this notebook will guide the data cleaning and exploratory data analysis phases of the project.

# %% [markdown]
# ## Import Required Libraries
#
# This section imports the Python libraries required for data profiling and analysis.
#
# - Pandas is used for loading, manipulating, and analyzing tabular data.
# - NumPy is used for numerical operations and array-based computations.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the Dataset
#
# In this section, the dataset is loaded into a Pandas DataFrame. This allows us to inspect its structure and perform data profiling.

# %%
df = pd.read_csv("/content/MentalHealthSurvey.csv")

# %% [markdown]
# ## Dataset Overview
#
# The first step in data profiling is to understand the size of the dataset. We will determine the number of rows and columns.

# %%
df.shape
# Out:
# (87, 21)

# %% [markdown]
# ### Observation
#
# The dataset contains 87 rows and 21 columns. This indicates that there are 87 observations available for analysis, each described by 21 variables. The dataset is relatively small, making it suitable for exploratory analysis in memory.

# %%
6. Data Types

# %%
7. Missing Values

# %%
8. Duplicate Records

# %%
9. Unique Values

# %%
10. Summary Statistics

# %%
11. Initial Observations
